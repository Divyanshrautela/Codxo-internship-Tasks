# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshrautela/Codxo-internship-Tasks/blob/master/ai_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cnt = 0
while (cnt < 3):
  cnt = cnt + 1
  print("Hello Geek")
else:
    print("In Else Block")
# Out:
# Hello Geek
# Hello Geek
# Hello Geek
# In Else Block

# %%
even={x:x**2 for x in range(10)}
print(even )
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
for i in range(3):
 for j in range(2):
  print(f"i:{i} and j:{j}")
# Out:
# i:0 and j:0
# i:0 and j:1
# i:1 and j:0
# i:1 and j:1
# i:2 and j:0
# i:2 and j:1

# %%
mixed_list=[1,"apple" ,True ,3.14]
print(mixed_list)
# Out:
# [1, 'apple', True, 3.14]

# %%
fruits=["apple","banana","mango","guava","kiwi"]

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'guava', 'kiwi']

# %%
# fruits[1:]="ginger"

# %%
# fruits

# %%
fruits.sort()

# %%
fruits
# Out:
# ['apple', 'banana', 'guava', 'kiwi', 'mango']

# %%
list=[]
for x in range(10):
  list.append(x**2)

print(list)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
[x**2 for x in range(11)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
